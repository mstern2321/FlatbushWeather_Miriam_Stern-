# %% [markdown]
# <a href="https://colab.research.google.com/github/mstern2321/FlatbushWeather_Miriam_Stern-/blob/main/abstract_design_polymorphism_homework_90min.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework: Abstract Design, Inheritance, and Polymorphism
#
# **Estimated time:** 90 minutes
# **Topics:** inheritance, abstract classes, abstract methods, static methods, class methods, overriding, polymorphism, and simple word-game controllers.
#
# ## Student Instructions
#
# Complete each section in order.
# Run your cells as you go.
# Use clear variable names and write short comments where helpful.
#
# The main design idea for this homework is:
#
# > An abstract parent class defines what every child class must be able to do, while each child class decides how to do it.

# %% [markdown]
# # Support Guide — Abstract Design, Inheritance, and Polymorphism
#
# ---
#
# # 1. Three Kinds of Methods
#
# ## Instance Methods
#
# Instance methods work with ONE specific object.
#
# Python automatically provides:
#
# ```python
# self
# ```
#
# Example:
#
# ```python
# class Student:
#
#     def __init__(self, name):
#         self.name = name
#
#     def show_name(self):
#         return self.name
# ```
#
# Why does `show_name()` need `self`?
#
# Because different objects may have different names.
#
# ---
#
# # Class Methods
#
# Class methods work with the CLASS itself.
#
# Python automatically provides:
#
# ```python
# cls
# ```
#
# Class methods are often used for:
# - counters,
# - shared configuration,
# - factory methods,
# - class-level data.
#
# Example:
#
# ```python
# class Student:
#
#     student_count = 0
#
#     def __init__(self, name):
#         self.name = name
#         Student.student_count += 1
#
#     @classmethod
#     def get_student_count(cls):
#         return cls.student_count
# ```
#
# Usage:
#
# ```python
# print(Student.get_student_count())
# ```
#
# ---
#
# # Static Methods
#
# Static methods:
# - do NOT need `self`
# - do NOT need `cls`
#
# They are usually:
# - helpers,
# - validators,
# - formatters,
# - utility methods.
#
# Example:
#
# ```python
# class GuessHelper:
#
#     @staticmethod
#     def clean_text(text: str):
#         return text.lower().strip()
# ```
#
# Usage:
#
# ```python
# GuessHelper.clean_text(" A ")
# ```
#
# Important:
# We do NOT create an object.
#
# ---
#
# # 2. Abstract Classes
#
# An abstract class represents:
# - a blueprint,
# - a contract,
# - or a general category.
#
# It is NOT meant to be instantiated directly.
#
# ---
#
# # Importing ABC
#
# ```python
# from abc import ABC, abstractmethod
# ```
#
# ---
#
# # Example
#
# ```python
# from abc import ABC, abstractmethod
#
# class Animal(ABC):
#
#     @abstractmethod
#     def speak(self):
#         pass
# ```
#
# This class says:
#
# > “Every child class MUST implement speak().”
#
# ---
#
# # Why Abstract Classes Matter
#
# Abstract classes help:
# - organize large systems,
# - enforce consistency,
# - reduce duplication,
# - and guarantee important behavior.
#
# ---
#
# # Important Rule
#
# This will FAIL:
#
# ```python
# animal = Animal()
# ```
#
# because:
# - `Animal` is incomplete,
# - `speak()` has not been implemented.
#
# ---
#
# # 3. Child Classes and Contracts
#
# A child class must implement ALL abstract methods.
#
# Example:
#
# ```python
# class Dog(Animal):
#
#     def speak(self):
#         print("Woof!")
# ```
#
# Now:
#
# ```python
# dog = Dog()
# ```
#
# works correctly.
#
# ---
#
# # 4. Inheritance
#
# Inheritance allows a child class to reuse parent behavior.
#
# Example:
#
# ```python
# class Animal:
#
#     def eat(self):
#         print("Eating")
#
#
# class Dog(Animal):
#     pass
# ```
#
# Now:
#
# ```python
# d = Dog()
# d.eat()
# ```
#
# works because:
# `Dog` inherited `eat()`.
#
# ---
#
# # 5. Overriding
#
# Overriding happens when a child creates its OWN version of a parent method.
#
# Example:
#
# ```python
# class Animal:
#
#     def speak(self):
#         print("Some sound")
#
#
# class Dog(Animal):
#
#     def speak(self):
#         print("Woof!")
# ```
#
# `Dog` overrides the parent implementation.
#
# ---
#
# # 6. Polymorphism
#
# Polymorphism means:
# different objects can respond to the SAME method name differently.
#
# Example:
#
# ```python
# class Dog:
#
#     def speak(self):
#         print("Woof!")
#
#
# class Cat:
#
#     def speak(self):
#         print("Meow!")
#
#
# animals = [Dog(), Cat()]
#
# for animal in animals:
#     animal.speak()
# ```
#
# Output:
#
# ```python
# Woof!
# Meow!
# ```
#
# Same method call:
#
# ```python
# speak()
# ```
#
# Different behavior.
#
# ---
#
# # 7. Sets
#
# Sets are very useful for tracking guesses.
#
# Why?
# - no duplicates
# - fast lookup
# - excellent for membership testing
#
# Example:
#
# ```python
# guesses = set()
#
# guesses.add("a")
# guesses.add("b")
# ```
#
# Check membership:
#
# ```python
# "a" in guesses
# ```
#
# ---
#
# # 8. The `all()` Function
#
# `all()` returns `True`
# ONLY if every condition is `True`.
#
# Example:
#
# ```python
# numbers = [True, True, True]
#
# print(all(numbers))
# ```
#
# Output:
#
# ```python
# True
# ```
#
# ---
#
# # Example in a Word Game
#
# ```python
# return all(letter in self.guesses for letter in self.secret_word)
# ```
#
# Meaning:
#
# > “Has every letter in the secret word been guessed?”
#
# ---
#
# # 9. Using `input()`
#
# Example:
#
# ```python
# guess = input("Enter a letter: ")
# ```
#
# Often we clean the input:
#
# ```python
# guess = guess.lower().strip()
# ```
#
# ---
#
# # 10. Interactive Loop Example
#
# ```python
# while not game.check_game_over():
#
#     guess = input("Enter a letter: ")
#
#     correct = game.make_guess(guess)
#
#     if correct:
#         print("Correct!")
#     else:
#         print("Incorrect!")
# ```
#
# This repeatedly:
# - asks for input,
# - processes guesses,
# - and checks whether the game is complete.
#
# ---
#
# # 11. Design Thinking
#
# A parent class answers:
#
# > “What must all subclasses be able to do?”
#
# Child classes answer:
#
# > “How will I do it?”
#
# That separation is one of the major strengths of object-oriented design.

# %% [markdown]
# ## Part 1 — Concept Review Questions (~15 minutes)
#
# Answer in the markdown cell below.
#
# 1. What is the difference between an instance method, a class method, and a static method?
# 2. What automatic parameter does Python provide for each one?
# 3. Why can an abstract class not be instantiated directly?
# 4. What is the purpose of an abstract method?
# 5. If several child classes implement an abstract method with only `pass`, what might that suggest about the parent class design?

# %% [markdown]
# ### Your Answers
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.

# %%
class GuessTools:
  def clean_guess(text: str) -> str:
    return text.lower().strip()
  def is_valid_guess(text: str) -> bool:
    return len(text) == 1 and text.isalpha()
GuessTools.clean_guess(" A ")
GuessTools.is_valid_guess("a")     # True
GuessTools.is_valid_guess("ab")    # False
GuessTools.is_valid_guess("1")     # False
# Out:
# False

# %% [markdown]
# ## Part 2 — Static Method Practice (~15 minutes)
#
# Create a utility class named `GuessTools`.
#
# This class should contain two static methods:
#
# ### `clean_guess(text: str) -> str`
#
# Returns the lowercase version of the text with whitespace removed from the beginning and end.
#
# Example:
#
# ```python
# GuessTools.clean_guess(" A ")
# ```
#
# should return:
#
# ```python
# "a"
# ```
#
# ### `is_valid_guess(text: str) -> bool`
#
# Returns `True` if the text is exactly one alphabetic letter.
# Returns `False` otherwise.
#
# Examples:
#
# ```python
# GuessTools.is_valid_guess("a")     # True
# GuessTools.is_valid_guess("ab")    # False
# GuessTools.is_valid_guess("1")     # False
# ```

# %% [markdown]
# ## Part 3 — Abstract Parent Class (~10 minutes)
#
# Create an abstract parent class named `MiniGameController`.
#
# This class represents the contract for all mini word games.
#
# It should require every child class to implement:
#
# ```python
# play()
# make_guess(letter: str)
# check_game_over()
# ```
#
# Remember:
#
# ```python
# from abc import ABC, abstractmethod
# ```

# %%
# your code here
from abc import ABC, abstractmethod
class MiniGameController(ABC):
  @abstractmethod
  def play(self):
    pass
  @abstractmethod
  def make_guess(self, letter: str):
    pass
  @abstractmethod
  def check_game_over(self):
    pass

# %% [markdown]
# ## Part 4 — Concrete Child Class: `ScoreWordGame` (~20 minutes)
#
# Create a child class named `ScoreWordGame` that inherits from `MiniGameController`.
#
# ### Required Instance Attributes
#
# Each `ScoreWordGame` object should have:
#
# ```python
# secret_word
# guesses
# score
# ```
#
# ### Required Methods
#
# #### `play()`
#
# Prints a welcome message.
#
# #### `make_guess(letter: str)`
#
# This method should:
#
# 1. clean the guess using `GuessTools.clean_guess()`
# 2. validate the guess using `GuessTools.is_valid_guess()`
# 3. add valid guesses to the guesses set
# 4. add 10 points if the guess is correct
# 5. subtract 5 points if the guess is incorrect
# 6. return `True` if the guess is correct
# 7. return `False` if the guess is incorrect
#
# If the guess is invalid, print a message and return `False`.
#
# #### `check_game_over()`
#
# Returns `True` if every letter in the secret word has been guessed.
# Otherwise returns `False`.

# %%
# your code here
class ScoreWordGame(MiniGameController):
  def __init__(self, secret_word):
    self.secret_word = secret_word
    self.score = 0
    self.guesses = []
  def play(self):
    print("Welcome to Score Word Game!")
  def make_guess(self, letter: str):
    guess = GuessTools.clean_guess(letter)
    if GuessTools.is_valid_guess(guess):
      self.guesses.append(guess)
    if guess in self.secret_word:
      self.score += 10
      return True
    else:
      self.score -= 5
      return False
  def check_game_over(self):
    return all(letter in self.guesses for letter in self.secret_word)

# %% [markdown]
# ## Part 5 — Another Concrete Child Class: `CategoryWordGame` (~15 minutes)
#
# Create another child class named `CategoryWordGame`.
#
# This class also inherits from `MiniGameController`.
#
# ### Required Instance Attributes
#
# ```python
# secret_word
# category
# guesses
# ```
#
# ### Required Methods
#
# #### `play()`
#
# Prints a welcome message and displays the category.
#
# Example:
#
# ```python
# Welcome to Category Word Game!
# Category: Animals
# ```
#
# #### `make_guess(letter: str)`
#
# This method should:
#
# 1. clean the guess
# 2. validate the guess
# 3. add valid guesses to the guesses set
# 4. return `True` if the guess is in the secret word
# 5. return `False` otherwise
#
# #### `check_game_over()`
#
# Returns `True` if every letter in the secret word has been guessed.
# Otherwise returns `False`.

# %%
# your code here
class CategoryWordGame(MiniGameController):
  def __init__(self, secret_word, category):
    self.secret_word = secret_word
    self.category = category
    self.guesses = []
  def play(self):
    print("Welcome to Category Word Game!")
    print(f"Category: {self.category}")
  def make_guess(self, letter: str):
    cleaned_letter = GuessTools.clean_guess(letter)
    if GuessTools.is_valid_guess(cleaned_letter):
      self.guesses.append(cleaned_letter)
      return True
    return False
  def check_game_over(self):
    return all(letter in self.guesses for letter in self.secret_word)

# %% [markdown]
# ## Part 6 — Polymorphism Practice (~15 minutes)
#
# Now create a list containing different child objects.
#
# Even though the objects come from different classes, they all share the same interface because they inherit from `MiniGameController`.
#
# Use a loop to call:
#
# ```python
# play()
# make_guess()
# check_game_over()
# ```
#
# on each game.
#
# This demonstrates polymorphism.

# %%
# your code here
my_lst = [ScoreWordGame("dog"), CategoryWordGame("cat", "animals")]
for game in my_lst:
  game.play()
  game.make_guess("c")
  print(game.check_game_over())
# Out:
# Welcome to Score Word Game!
# False
# Welcome to Category Word Game!
# Category: animals
# False

# %% [markdown]
# ## Part 7 — Interactive Main Program (~10 minutes)
#
# Choose ONE of your concrete game classes and make it interactive.
#
# Recommended choice:
#
# ```python
# ScoreWordGame("apple")
# ```
#
# Use a `while` loop that continues until `check_game_over()` returns `True`.
#
# Inside the loop:
#
# 1. Ask the user for a guess using `input()`
# 2. Call `make_guess()`
# 3. Print whether the guess was correct
# 4. Print the guesses so far
# 5. If using `ScoreWordGame`, print the score
#
# When the game ends, print a congratulations message.

# %%
# your code here
class ScoreWordGame(MiniGameController):
  def __init__(self, secret_word):
    self.secret_word = secret_word
    self.score = 0
    self.guesses = []
  def play(self):
    print("Welcome to Score Word Game!")
  def make_guess(self):
    while not self.check_game_over():
      letter = input("Enter a letter: ")
      guess = GuessTools.clean_guess(letter)
      if GuessTools.is_valid_guess(guess):
        self.guesses.append(guess)
      if guess in self.secret_word:
        print("correct")
        print(self.guesses)
        self.score += 10
        print(self.score)
        return True
      else:
        print("incorrect")
        print(self.guesses)
        self.score -= 5
        print(self.score)
        return False
  def check_game_over(self):
    return all(letter in self.guesses for letter in self.secret_word)

# %% [markdown]
# ## Part 8 — Reflection (~5 minutes)
#
# Answer in the markdown cell below.
#
# 1. How does the abstract parent class help organize the game design?
# 2. How did inheritance reduce repeated design work?
# 3. Where did you see polymorphism in this homework?
# 4. Why might a large software team prefer this design over separate unrelated classes?

# %% [markdown]
# ### Your Reflection
#
# 1.
#
# 2.
#
# 3.
#
# 4.

# %% [markdown]
# # PART 9 Class Method and Class Attribute
#
# Add a class attribute to one or both game classes:
#
# ```python
# number_of_games_created = 0
# ```
#
# Every time a game object is created, increase the counter.
#
# Then create a class method:
#
# ```python
# @classmethod
# def get_number_of_games_created(cls):
#     return cls.number_of_games_created
# ```
#
# Test your method after creating multiple game objects.

# %%
# your code here
